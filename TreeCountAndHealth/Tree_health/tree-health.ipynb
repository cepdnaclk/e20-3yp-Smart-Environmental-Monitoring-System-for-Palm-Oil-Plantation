# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.1/922.1 kB 24.9 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="i00C8995sdAj2VLWeVej")
project = rf.workspace("health-detection").project("oil-palm-health-detection")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Oil-Palm-Health-Detection-2 in yolov5pytorch:: 100%|██████████| 4618/4618 [00:01<00:00, 4131.07it/s]

# %%
dataset.location
# Out:
# '/kaggle/working/Oil-Palm-Health-Detection-2'

# %%
# !sed -i 's|train: .*|train: /kaggle/working/Oil-Palm-Health-Detection-2/train/images|' /kaggle/working/Oil-Palm-Health-Detection-2/data.yaml
# !sed -i 's|val: .*|val: /kaggle/working/Oil-Palm-Health-Detection-2/valid/images|' /kaggle/working/Oil-Palm-Health-Detection-2/data.yaml
# !sed -i 's|test: .*|test: /kaggle/working/Oil-Palm-Health-Detection-2/test/images|' /kaggle/working/Oil-Palm-Health-Detection-2/data.yaml

# %%
cat /kaggle/working/Oil-Palm-Health-Detection-2/data.yaml
# Out:
# names:
# - Healthy
# - Unhealthy
# nc: 2
# roboflow:
#   license: CC BY 4.0
#   project: oil-palm-health-detection
#   url: https://universe.roboflow.com/health-detection/oil-palm-health-detection/dataset/2
#   version: 2
#   workspace: health-detection
# test: /kaggle/working/Oil-Palm-Health-Detection-2/test/images
# train: /kaggle/working/Oil-Palm-Health-Detection-2/train/images
# val: /kaggle/working/Oil-Palm-Health-Detection-2/valid/images

# %%
# !yolo task=detect mode=train model=yolov5xu.pt data=/kaggle/working/Oil-Palm-Health-Detection-2/data.yaml epochs=50 imgsz=640 batch=8
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|█████████████████████████████████████████| 186M/186M [00:01<00:00, 168MB/s]
# Ultralytics 8.3.81 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model=best.pt data=/kaggle/working/Oil-Palm-Health-Detection-2/data.yaml imgsz=640!yolo task=detect mode=val \
    model=/kaggle/working/runs/detect/train/weights/best.pt \
    data=/kaggle/working/Oil-Palm-Health-Detection-2/data.yaml \
    imgsz=640
# Out:
# Ultralytics 8.3.81 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv5x summary (fused): 150 layers, 97,154,534 parameters, 0 gradients, 246.0 GFLOPs
# val: Scanning /kaggle/working/Oil-Palm-Health-Detection-2/valid/labels.cache...
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        461      29984      0.995      0.997      0.995      0.992
#                Healthy        461      29563      0.996      0.996      0.995      0.991
#              Unhealthy        222        421      0.995      0.997      0.995      0.993
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Speed: 0.9ms preprocess, 63.8ms inference, 0.0ms loss, 4.6ms postprocess per image
# ...

# %%
# !yolo task=detect mode=predict \
    model=/kaggle/working/runs/detect/train/weights/best.pt \
    source=/kaggle/working/Oil-Palm-Health-Detection-2/train/images/52000_20000_622_3468_jpg.rf.4548be5e6403702a090efcfb2af163d6.jpg\
    imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 957, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/model.py", line 23, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 148, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 291, in _load
# ...
